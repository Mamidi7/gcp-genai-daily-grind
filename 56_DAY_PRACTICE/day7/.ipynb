# %%
@tool
def calculator(expression:str)->str:
    try: 
        result = eval(expression)
        return str(result)
    except exception as e:
        return f"errror: {e}"

@tool
def search_gemini(query:str)->str:
    response = llm.invoke(query)
    return response.content

tools=[calculator,search_gemini]

# %%
#tool1: calculator 
@tool 
def calculator(expression:str)-> str:
    """ just try chesthunna for calculator """
    try:
        result = eval(expression)
        return str(result)
    except Exception as e:
        return f"Error: {e}"

#tool2: search(using google gemini)
@tool2
def search_gemini(query: str) -> str:
    """ search through gemini """
    response = llm.invoke(query)
    return response.content

tools = [calculator,search_gemini]
print(f"Tools created")

# %%
@tool
def calculator(expression: str)-> str:
    try:
        result=eval(expression)
        return str(result)
    except: Exception as e: 
        return f"error: {e}"

@tool
def search_engine(query:str)->str:
    response = llm.invoke(query)
    return response.content

tools = [calculator,search_engine]
print("tools created")
