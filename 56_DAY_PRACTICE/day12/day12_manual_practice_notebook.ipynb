# %% [markdown]
# # Day 12 Manual Practice Notebook\n
# \n
# FastAPI Basics (manual practice only).

# %% [markdown]
# ## Non-Hallucination Rules\n
# - Do not assume output. Run and verify manually.\n
# - Save actual command output as evidence.\n
# - Do not mark day finished unless all artifacts are complete.

# %% [markdown]
# ## Start -> Finish Map\n
# 1. Read concept notes (`prep_notes.md`).\n
# 2. Understand API contract (`api_contract.md`).\n
# 3. Write `main.py` manually.\n
# 4. Run manual curl tests from `verification_runbook.md`.\n
# 5. Save evidence + debug + interview artifacts.

# %% [markdown]
# ## Day 12 Status Log (Update in-place)\n
# - [ ] Step 1: `/health` endpoint\n
# - [ ] Step 2: `/echo` endpoint\n
# - [ ] Step 3: Pydantic model\n
# - [ ] Step 4: Valid + invalid run\n
# - [ ] Step 5: Interview conversion

# %% [markdown]
# ## Topic 1 - `/health` Endpoint\n
# Goal: Return simple service health response.

# %%
# Write your /health endpoint code snippet here\n

# %% [markdown]
# ### Check Question\n
# Why is `/health` needed before complex APIs?

# %%
# Your answer (2-4 lines)\n

# %% [markdown]
# ## Topic 2 - `/echo` Endpoint\n
# Goal: Accept input and return it in response.

# %%
# Write your /echo endpoint code snippet here\n

# %% [markdown]
# ## Topic 3 - Pydantic Request Model\n
# Goal: Validate request body before handler logic.

# %%
# Define your BaseModel here\n

# %% [markdown]
# ## Topic 4 - Manual Testing Log\n
# Paste actual curl outputs for: health, valid echo, invalid echo.

# %%
# Paste outputs here (no assumptions)\n

# %% [markdown]
# ## Topic 5 - Interview Conversion\n
# Write simple versions:\n
# - 30-second answer\n
# - 90-second STAR\n
# - 3-minute walkthrough

# %%
# Write your 30s / 90s / 3-min answers here\n

# %% [markdown]
# ## Error Journal Prompt\n
# For one failure, write: symptom, root cause, fix, prevention, impact.

# %%
# Write one debug case here\n
